# %% [markdown]
# ---
# # 🎤Slicing (Practice)
# ---
# - Anas Abu Alhaija

# %% [markdown]
# For this assignment, you will continue to work with the insurance dataset from the Loading Data Practice assignment.

# %% [markdown]
# [Insurance Data](https://drive.google.com/file/d/1-7mcBguuzAV7JWVu2XCpgAO-fO6X2cl0/view?usp=sharing)

# %%
# file path
fpath = "/content/drive/MyDrive/CodingDojo/01-Fundamentals/Week02/Data/insurance_mod.csv"

# %%
# import pandas
import pandas as pd

# %%
# load in data as a pandas dataframe
df_insurance = pd.read_csv(fpath)
# preview the first five rows
df_insurance.head()
# Out:
#    age     sex     bmi  children  smoker     region  charges
# 0   19  female  27.900         0       1  southwest  16885.0
# 1   18    male  33.770         1       0  southeast   1726.0
# 2   28    male  33.000         3       0  southeast   4449.0
# 3   33    male  22.705         0       0  northwest  21984.0
# 4   32    male  28.880         0       0  northwest   3867.0

# %% [markdown]
# 1) Slice the row for the customer at index 50
#
# - Use single brackets so the output is a Pandas Series

# %%
df_insurance.loc[50]
# Out:
# age                18
# sex            female
# bmi            35.625
# children            0
# smoker              0
# region      northeast
# charges        2211.0
# Name: 50, dtype: object

# %% [markdown]
# 2)Slice the row for the customer at index 50
#
# - Use double brackets so the output slice is a Pandas Dataframe

# %%
df_insurance.loc[[50]]
# Out:
#     age     sex     bmi  children  smoker     region  charges
# 50   18  female  35.625         0       0  northeast   2211.0

# %% [markdown]
# 3) Find out if the customer at index 20 was a male or female (by slicing index 20 and column "Sex")

# %%
df_insurance.loc[20,'sex']
# Out:
# 'female'

# %% [markdown]
# 4) Slice the entire smoker column using square brackets

# %%
df_insurance[['smoker']]
# Out:
#       smoker
# 0          1
# 1          0
# 2          0
# 3          0
# 4          0
# ...      ...
# 1333       0
# 1334       0
# 1335       0
# 1336       0
# 1337       1
#
# [1338 rows x 1 columns]

# %% [markdown]
# 5) Slice the entire smoker column using .loc

# %%
df_insurance.loc[:,['smoker']]
# Out:
#       smoker
# 0          1
# 1          0
# 2          0
# 3          0
# 4          0
# ...      ...
# 1333       0
# 1334       0
# 1335       0
# 1336       0
# 1337       1
#
# [1338 rows x 1 columns]

# %% [markdown]
# 6) Slice the entire smoker column using either method, but this time save it as a variable called "smoker"
# - Calculate the sum of the smoker variable to see how many of the customers smoke
# - Calculate the mean of the smoker variable using .mean() to see the ratio of smokers in the dataset

# %%
smoker = df_insurance['smoker']

# %%
smoker.sum()
# Out:
# 274

# %% [markdown]
# The number of customers smoke is 274

# %%
smoker.mean()
# Out:
# 0.20478325859491778

# %% [markdown]
# The ratio is 20%

# %% [markdown]
# 🔚
